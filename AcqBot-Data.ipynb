# %%
# !pip install chromadb
# !pip install langchain
# !pip install langchain-text-splitters
# !pip install pdfplumber

# %%
import chromadb
import langchain
from langchain_text_splitters import RecursiveCharacterTextSplitter
import pdfplumber
import os
import gc

# %%
files = [
    {
        "title": "Federal Acquisition Regulation",
        "source_url": "https://www.acquisition.gov/sites/default/files/current/far/pdf/FAR.pdf",
        "filename": "FAR.pdf",
        "last_update": 2018
    },
    {
        "title": "Defense Federal Acquisition Regulation",
        "source_url": "https://www.acquisition.gov/sites/default/files/current/dfars/pdf/DFARS.pdf",
        "filename": "DFARS.pdf",
        "last_update": 2020
    },
    {
        "title": "USC Title 10, Subtitle A, Part V, Sub Part E, Chapter 301, Sub Chapter II, Section 4022",
        "source_url": "https://www.govinfo.gov/content/pkg/USCODE-2024-title10/pdf/USCODE-2024-title10-subtitleA-partV-subpartE-chap301-subchapII-sec4022.pdf",
        "filename": "USCODE-2024-title10.4022.pdf",
        "last_update": 2024
    }
]

# %%
os.makedirs("./lib", exist_ok=True)
os.makedirs("./chroma_db", exist_ok=True)

# %%
client = chromadb.PersistentClient("./chroma_db")

collection = client.get_or_create_collection(
    name="RAG_Assistant",
    metadata={"hnsw:space": "cosine"})

# %%
import gc
import json
import os
import pickle
from pathlib import Path
from typing import Any

import chromadb
import pdfplumber
from langchain.text_splitter import RecursiveCharacterTextSplitter

# ------------------------------------------------------------------
# Global config
# ------------------------------------------------------------------
CHROMA_DIR = "./chroma_db"          # where ChromaDB persists
COLLECTION_NAME = "RAG_Assistant"
LIB_DIR = "./lib"                 # folder that contains the PDFs

# ------------------------------------------------------------------
# Main helper
# ------------------------------------------------------------------
def pdf2pickle(
    lib_dir: str = LIB_DIR,
    chroma_dir: str = CHROMA_DIR,
    collection_name: str = COLLECTION_NAME,
    export_prefix: str = "precomputed_docs",
) -> None:
    """
    1. Extract text from every PDF listed in the global `files`.
    2. Chunk it (1500 chars, 200 overlap).
    3. Store chunks in a ChromaDB collection.
    4. Export the collection to:
       - {export_prefix}.pkl  (documents, metadatas, embeddings)
       - {export_prefix}.json (documents, metadatas only – VCS friendly)
    """
    # ----------------------------------------------------------
    # 0.  Set up text-splitter
    # ----------------------------------------------------------
    text_splitter = RecursiveCharacterTextSplitter(
        separators=["\n\n", "\n", ". ", "? ", "! "],
        chunk_size=1500,
        chunk_overlap=200,
    )

    documents: list[str] = []
    metadatas: list[dict[str, Any]] = []
    ids: list[str] = []

    # ----------------------------------------------------------
    # 1.  Connect to / create ChromaDB collection
    # ----------------------------------------------------------
    os.makedirs(chroma_dir, exist_ok=True)
    client = chromadb.PersistentClient(path=chroma_dir)

    try:
        client.delete_collection(collection_name)
        collection = client.create_collection(
            name=collection_name,
            metadata={"hnsw:space": "cosine"},
        )
    except Exception:
        collection = client.get_or_create_collection(
            name=collection_name,
            metadata={"hnsw:space": "cosine"},
        )

    # ----------------------------------------------------------
    # 2.  PDF text-extraction helper
    # ----------------------------------------------------------
    def extract_text_from_pdf(pdf_path: str, max_pages: int | None = None) -> str | None:
        text = ""
        try:
            with pdfplumber.open(pdf_path) as pdf:
                total_pages = len(pdf.pages)
                if max_pages:
                    total_pages = min(total_pages, max_pages)

                for i, page in enumerate(pdf.pages):
                    if i >= total_pages:
                        break
                    page_text = page.extract_text()
                    if page_text:
                        text += page_text + "\n"

                    # periodic garbage collection to keep memory low
                    if i % 10 == 0:
                        gc.collect()
        except Exception as e:
            print(f"[ERROR] extracting text from {pdf_path}: {e}")
            return None
        return text or None

    # ----------------------------------------------------------
    # 3.  Process every file
    # ----------------------------------------------------------
    for file_info in files:
        filename = file_info["filename"]
        print(f"Processing {filename}...")
        content = extract_text_from_pdf(Path(lib_dir) / filename)
        if not content:
            print(f"  Skipping {filename} – could not extract text")
            continue

        chunks = text_splitter.create_documents([content])
        print(f"  Created {len(chunks)} chunks from {filename}")

        for idx, chunk in enumerate(chunks):
            documents.append(chunk.page_content)
            metadatas.append(
                {
                    "title": file_info["title"],
                    "source_url": file_info["source_url"],
                    "chunk_idx": idx,
                    "filename": filename,
                }
            )
            ids.append(f"{filename}_{idx}")

    # ----------------------------------------------------------
    # 4.  Bulk insert into ChromaDB
    # ----------------------------------------------------------
    if documents:
        batch_size = 25
        for i in range(0, len(documents), batch_size):
            batch_end = min(i + batch_size, len(documents))
            collection.add(
                documents=documents[i:batch_end],
                metadatas=metadatas[i:batch_end],
                ids=ids[i:batch_end],
            )
        print(f"Successfully added {len(documents)} document chunks to ChromaDB")
    else:
        print("No documents were added to ChromaDB")
        return  # nothing to export

    # ----------------------------------------------------------
    # 5.  Export collection to disk (pickle + JSON)
    # ----------------------------------------------------------
    def save_preprocessed_data() -> None:
        """Save processed documents and embeddings"""
        all_docs = collection.get(include=["documents", "metadatas", "embeddings"])

        # Pickle (fast load, includes embeddings)
        with open(f"{export_prefix}.pkl", "wb") as f:
            pickle.dump(
                {
                    "documents": all_docs["documents"],
                    "metadatas": all_docs["metadatas"],
                    "embeddings": all_docs["embeddings"],
                },
                f,
            )

        # JSON (human-readable, no embeddings)
        with open(f"{export_prefix}.json", "w", encoding="utf-8") as f:
            json.dump(
                {"documents": all_docs["documents"], "metadatas": all_docs["metadatas"]},
                f,
                indent=2,
                ensure_ascii=False,
            )

        print(f"Saved {len(all_docs['documents'])} documents to {export_prefix}.pkl / .json")

    save_preprocessed_data()

# %%
pdf2pickle("./lib/")
# Out:
# Processing FAR.pdf...
#   Created 5049 chunks from FAR.pdf
# Processing DFARS.pdf...
#   Created 2577 chunks from DFARS.pdf
# Processing USCODE-2024-title10.4022.pdf...
#   Created 26 chunks from USCODE-2024-title10.4022.pdf
# Successfully added 7652 document chunks to ChromaDB
# Saved 7652 documents to precomputed_docs.pkl / .json
