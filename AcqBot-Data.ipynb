# %%
# !pip install --upgrade faiss-cpu langchain-community sentence-transformers
# !pip install --upgrade langchain
# !pip install --upgrade -qU langchain-text-splitters
# !pip install pdfplumber 
# !pip install spacy
# !pip install lxml
# !pip install nltk
# !pip install dotenv
# !pip install --upgrade langchain-huggingface
# Out:
# Requirement already satisfied: faiss-cpu in c:\users\pwdev\anaconda3\lib\site-packages (1.13.2)
# Requirement already satisfied: langchain-community in c:\users\pwdev\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: sentence-transformers in c:\users\pwdev\anaconda3\lib\site-packages (5.2.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\pwdev\anaconda3\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\pwdev\anaconda3\lib\site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (1.2.6)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (3.11.10)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (0.4.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\pwdev\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\pwdev\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pwdev\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pwdev\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pwdev\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\pwdev\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\pwdev\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\pwdev\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\pwdev\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\pwdev\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in c:\users\pwdev\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: certifi in c:\users\pwdev\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\pwdev\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: idna in c:\users\pwdev\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.7)
# Requirement already satisfied: sniffio in c:\users\pwdev\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pwdev\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pwdev\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pwdev\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\pwdev\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\pwdev\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\pwdev\anaconda3\lib\site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in c:\users\pwdev\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\pwdev\anaconda3\lib\site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: scikit-learn in c:\users\pwdev\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\pwdev\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\pwdev\anaconda3\lib\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: filelock in c:\users\pwdev\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pwdev\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\pwdev\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pwdev\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pwdev\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pwdev\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\pwdev\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\pwdev\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\pwdev\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pwdev\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\pwdev\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pwdev\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pwdev\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pwdev\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: langchain in c:\users\pwdev\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain) (1.2.6)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.4.5)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\pwdev\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\pwdev\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\pwdev\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\pwdev\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\pwdev\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.2.0)
# Requirement already satisfied: certifi in c:\users\pwdev\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\pwdev\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: idna in c:\users\pwdev\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.7)
# Requirement already satisfied: sniffio in c:\users\pwdev\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pwdev\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pwdev\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pwdev\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.3.0)
# Requirement already satisfied: pdfplumber in c:\users\pwdev\anaconda3\lib\site-packages (0.11.8)
# Requirement already satisfied: pdfminer.six==20251107 in c:\users\pwdev\anaconda3\lib\site-packages (from pdfplumber) (20251107)
# Requirement already satisfied: Pillow>=9.1 in c:\users\pwdev\anaconda3\lib\site-packages (from pdfplumber) (11.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\pwdev\anaconda3\lib\site-packages (from pdfplumber) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\pwdev\anaconda3\lib\site-packages (from pdfminer.six==20251107->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\pwdev\anaconda3\lib\site-packages (from pdfminer.six==20251107->pdfplumber) (43.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\pwdev\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\pwdev\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.21)
# Requirement already satisfied: spacy in c:\users\pwdev\anaconda3\lib\site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (0.21.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (4.66.5)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pwdev\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pwdev\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pwdev\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pwdev\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pwdev\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.10.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\pwdev\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\pwdev\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\pwdev\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\pwdev\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\pwdev\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\pwdev\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pwdev\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: lxml in c:\users\pwdev\anaconda3\lib\site-packages (5.2.1)
# Requirement already satisfied: nltk in c:\users\pwdev\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\pwdev\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\pwdev\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pwdev\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\pwdev\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\pwdev\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: dotenv in c:\users\pwdev\anaconda3\lib\site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in c:\users\pwdev\anaconda3\lib\site-packages (from dotenv) (0.21.0)
# Requirement already satisfied: langchain-huggingface in c:\users\pwdev\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-huggingface) (0.36.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-huggingface) (1.2.6)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-huggingface) (0.22.1)
# Requirement already satisfied: filelock in c:\users\pwdev\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pwdev\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\pwdev\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pwdev\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (6.0.1)
# Requirement already satisfied: requests in c:\users\pwdev\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\pwdev\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pwdev\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.4.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (8.2.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\pwdev\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\pwdev\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.23.0)
# Requirement already satisfied: anyio in c:\users\pwdev\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (4.2.0)
# Requirement already satisfied: certifi in c:\users\pwdev\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\pwdev\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.0.2)
# Requirement already satisfied: idna in c:\users\pwdev\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (3.7)
# Requirement already satisfied: sniffio in c:\users\pwdev\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\pwdev\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\pwdev\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.0->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pwdev\anaconda3\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pwdev\anaconda3\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (2.3.0)
# Requirement already satisfied: colorama in c:\users\pwdev\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain-huggingface) (0.4.6)

# %%
import zipfile
import os
from langchain_community.document_loaders import UnstructuredXMLLoader, PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import SentenceTransformerEmbeddings
import os
from dotenv import load_dotenv
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings

# %%
dita_docs = []
for zip_file in ["./lib/FARDITA.zip", "./lib/DFARSDITA.zip"]: # Replace with your filenames
    with zipfile.ZipFile(zip_file, 'r') as zf:
        zf.extractall("dita_content")
    
    for root, dirs, files in os.walk("dita_content"):
        for file in files:
            if file.endswith(".dita") or file.endswith(".xml"):
                file_path = os.path.join(root, file)
                # Use UnstructuredXMLLoader for parsing DITA XML
                loader = UnstructuredXMLLoader(file_path)
                dita_docs.extend(loader.load())

# --- 2. Process PDF file ---

pdf_file = "./lib/USCODE-2024-title10.4022.pdf" # Replace with your filename
loader = PyPDFLoader(pdf_file)
pdf_docs = loader.load()

# Combine all documents
all_docs = dita_docs + pdf_docs
print(all_docs[:100])
# Out:
# [Document(metadata={'source': 'dita_content\\dita\\1.000.dita'}, page_content='1.000\n\nsubparts\xa0 1.2\n\n1.3\n\n1.4\n\nThis part sets forth basic policies and general information about the Federal Acquisition Regulations System including purpose, authority, applicability, issuance, arrangement, numbering, dissemination, implementation, supplementation, maintenance, administration, and deviation. '), Document(metadata={'source': 'dita_content\\dita\\1.101.dita'}, page_content='1.101\n\n1.301\n\nThe Federal Acquisition Regulations System is established for the codification and publication of uniform policies and procedures for acquisition by all executive agencies. The Federal Acquisition Regulations System consists of the Federal Acquisition Regulation (FAR), which is the primary document, and agency acquisition regulations that implement or supplement the FAR. The FAR System does not include internal agency guidance of the type described in '), Document(metadata={'source': 'dita_content\\dita\\1.102-1.dita'}, page_content='1.102-1\n\n(a)\n\nIntroduction.\n\n(b)\n\nVision'), Document(metadata={'source': 'dita_content\\dita\\1.102-2.dita'}, page_content='1.102-2\n\n(a)\n\n(1)\n\n(2)\n\n(3)\n\n(4)\n\n10.002\n\n15.201\n\n(5)\n\n(6)\n\n(7)\n\n(8)\n\n(b)\n\n(1)\n\n(2)\n\n(c)\n\n(1)\n\n(2)\n\n(3)\n\n(d)\n\nFulfill\npublic policy objectives'), Document(metadata={'source': 'dita_content\\dita\\1.102-3.dita'}, page_content='1.102-3\n\n(a)\n\n(1)\n\ne.g.\n\n(2)\n\nhttps://www.acquisition.gov/\u200b360\n\n(3)\n\ne.g.\n\n1.102-2\n\n42.302\n\n(b)\n\n52.201-1\n\n(c)'), Document(metadata={'source': 'dita_content\\dita\\1.102-4.dita'}, page_content='1.102-4\n\nThe purpose of defining the Federal Acquisition Team (Team) in the Guiding Principles is to ensure that participants in the System are identified beginning with the customer and ending with the contractor of the product or service. By identifying the team members in this manner, teamwork, unity of purpose, and open communication among the members of the Team in sharing the vision and achieving the goal of the System are encouraged. Individual team members will participate in the acquisition process at the appropriate time.'), Document(metadata={'source': 'dita_content\\dita\\1.102-5.dita'}, page_content='1.102-5\n\n(a)\n\n(b)\n\n(c)\n\n(d)\n\n(e)'), Document(metadata={'source': 'dita_content\\dita\\1.102.dita'}, page_content='1.102\n\n(a)\n\n(b)\n\n(1)\n\n(i)\n\n(ii)\n\n(iii)\n\n(2)\n\n(3)\n\n(4)\n\n(c)\n\n(d)'), Document(metadata={'source': 'dita_content\\dita\\1.103.dita'}, page_content='1.103\n\n(a)\n\n41 U.S.C. chapter 13\n\n(b)'), Document(metadata={'source': 'dita_content\\dita\\1.104.dita'}, page_content='1.104\n\npart\xa0 2\n\nThe FAR applies to all acquisitions as defined in '), Document(metadata={'source': 'dita_content\\dita\\1.105-1.dita'}, page_content='1.105-1\n\n(a)\n\n(1)\n\nFederal\nRegister\n\n(2)\n\nCode of Federal Regulations\n\n(3)\n\nhttps://www.acquisition.gov/browse/index/far\n\n(b)\n\nsubpart\xa0 1.3\n\n(c)\n\ne.g.,'), Document(metadata={'source': 'dita_content\\dita\\1.105-2.dita'}, page_content='1.105-2\n\n(a)\n\nGeneral.\n\n(b)\n\n(1)\n\n(2)\n\n1\n\ni\n\n(a)(1)(i)(A)(\n\n(c)\n\n(1)\n\n(2)\n\n(3)\n\n9.106-4\n\n(i)\n\npart\xa0 9\n\n(ii)\n\n9.1\n\n9.1\n\n(iii)\n\n9.106\n\n(iv)\n\n9.106-4\n\n(v)\n\n9.106-4\n\n(4)\n\ne.g.,\n\nFederal Register'), Document(metadata={'source': 'dita_content\\dita\\1.105-3.dita'}, page_content='1.105-3\n\nCopies of the FAR in CFR form may be purchased from the Bookstore of the Government Publishing Office (GPO), Washington, DC 20402.'), Document(metadata={'source': 'dita_content\\dita\\1.105.dita'}, page_content='1.105'), Document(metadata={'source': 'dita_content\\dita\\1.106.dita'}, page_content='1.106\n\n44 U.S.C. chapter 35\n\nThe Paperwork Reduction Act of 1980 (\n\nFAR\nsegment\n\nOMB Control Number\n\n14.205\n\n9000-0037\n\n15.201\n\n9000-0037\n\n15.305\n\n9000-0142\n\n15.407-2\n\n9000-0048\n\n19.301\n\n9000-0163\n\n22.8\n\n1 ...

# %%
# Split documents into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150) # Adjust chunk_size/overlap as needed
chunked_docs = text_splitter.split_documents(all_docs)

# Define a local, efficient embedding function
# "all-MiniLM-L6-v2" is lightweight and effective (384 dimensions)
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# Create a collection using the compatible embedding function
db = FAISS.from_documents(chunked_docs, embeddings)

# %%
# Add chunks to the collection
# (Rest of your code remains the same)
import uuid
doc_ids = [str(uuid.uuid4()) for _ in chunked_docs]
db.add(
    documents=[doc.page_content for doc in chunked_docs],
    metadatas=[doc.metadata for doc in chunked_docs],
    ids=doc_ids
)
db.save_local("faiss_index")
print("FAISS index saved successfully.")
print(f"Successfully processed {len(chunked_docs)} chunks and stored in FAISS at faiss_index")

# %% [markdown]
# db.save_local("faiss_index")
# print("FAISS index saved successfully.")

# %%
import shutil

# Initialize persistence
client = chromadb.PersistentClient(path="./chroma_db")
collection = client.get_or_create_collection(name="rag_docs")

# ... (Run your extraction and addition code from previous steps)

# 2026 Efficiency Tip: Zip the database folder for GitHub
# GitHub has a 100MB file limit; zipping minimizes the footprint of the SQLite/HNSW files.
shutil.make_archive("chroma_db_export", 'zip', "./chroma_db")
print("Database saved and compressed to chroma_db_export.zip")
